# %% [markdown]
# # Chapter2 --- Essential DataFrame Operations
# Selecting multiple DataFrame columns
# Selecting columns with methods
# Ordering column names sensibly
# Operating on the entire DataFrame
# Chaining DataFrame methods together
# Working with operators on a DataFrame
# Comparing missing values
# Transposing the direction of a DataFrame operation
# Determining college campus diversity

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
len(dir(random))
# Out:
# 63

# %%
len(dir(np))
# Out:
# 608

# %%
len(dir(plt))
# Out:
# 254

# %%
len(dir(pd))
# Out:
# 141

# %% [markdown]
# ## Selecting multiple DataFrame columns

# %%
cars=pd.read_csv("cars.csv")
cars
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
#pass in a list of the desired columns to the indexing operator
cars1=cars[["cylinders","hp","year","brand"]]
cars1
# Out:
#      cylinders   hp  year     brand
# 0            8  165  1972       US.
# 1            4   71  1980   Europe.
# 2            8  140  1971       US.
# 3            8  150  1971       US.
# 4            4   63  1978       US.
# ..         ...  ...   ...       ...
# 256          8  130  1980       US.
# 257          4   60  1979    Japan.
# 258          6  112  1983       US.
# 259          6  100  1972       US.
# 260          6  105  1977       US.
#
# [261 rows x 4 columns]

# %%
#There are instances when one column of a DataFrame needs to be selected. This is done by passing a single element list to the indexing operator:

cars["brand"]
# Out:
# 0           US.
# 1       Europe.
# 2           US.
# 3           US.
# 4           US.
#          ...
# 256         US.
# 257      Japan.
# 258         US.
# 259         US.
# 260         US.
# Name: brand, Length: 261, dtype: object

# %% [markdown]
# ## Selecting columns with methods

# %%
#. Use the get_dtype_counts method to output the number of columns with each specific data type:

cars1["year"].get_dtype_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [15], in <cell line: 3>()
#       1 #. Use the get_dtype_counts method to output the number of columns with each specific data type:
# ----> 3 cars1["year"].get_dtype_counts()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'get_dtype_counts'

# %%
# Use the select_dtypes method to select only the integer columns:

cars.select_dtypes()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <cell line: 3>()
#       1 # Use the select_dtypes method to select only the integer columns:
# ----> 3 cars.select_dtypes()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4333, in DataFrame.select_dtypes(self, include, exclude)
#    4330 selection = (frozenset(include), frozenset(exclude))
#    4332 if not any(selection):
# -> 4333     raise ValueError("at least one of include or exclude must be nonempty")
#    4335 # convert the myriad valid dtypes object to a single representation
#    4336 def check_int_infer_dtype(dtypes):
#
# ValueError: at least one of include or exclude must be nonempty

# %%
cars.select_dtypes(include=int)             # exclude
# Out:
#      cylinders   hp  time-to-60  year
# 0            8  165          12  1972
# 1            4   71          14  1980
# 2            8  140          11  1971
# 3            8  150          10  1971
# 4            4   63          17  1978
# ..         ...  ...         ...   ...
# 256          8  130          15  1980
# 257          4   60          16  1979
# 258          6  112          15  1983
# 259          6  100          16  1972
# 260          6  105          15  1977
#
# [261 rows x 4 columns]

# %%
#3. If you would like to select all the numeric columns, you may simply pass the string number to the include parameter:

cars.select_dtypes(include=['number'])
# Out:
#       mpg  cylinders   hp  time-to-60  year
# 0    14.0          8  165          12  1972
# 1    31.9          4   71          14  1980
# 2    17.0          8  140          11  1971
# 3    15.0          8  150          10  1971
# 4    30.5          4   63          17  1978
# ..    ...        ...  ...         ...   ...
# 256  17.0          8  130          15  1980
# 257  36.1          4   60          16  1979
# 258  22.0          6  112          15  1983
# 259  18.0          6  100          16  1972
# 260  22.0          6  105          15  1977
#
# [261 rows x 5 columns]

# %%
cars.select_dtypes(include=['number',"object"])
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
#4. An alternative method to select columns is with the filter method. This method is flexible and searches column names (or index labels) based on whichparameter is used.

cars.filter(like='ra')
# Out:
#         brand
# 0         US.
# 1     Europe.
# 2         US.
# 3         US.
# 4         US.
# ..        ...
# 256       US.
# 257    Japan.
# 258       US.
# 259       US.
# 260       US.
#
# [261 rows x 1 columns]

# %%
#5. The filter method allows columns to be searched through regular expressions with the regex parameter. Here, we search for all columns that have a digit
#somewhere in their name:
cars.filter(regex="\d")
# Out:
#      time-to-60
# 0            12
# 1            14
# 2            11
# 3            10
# 4            17
# ..          ...
# 256          15
# 257          16
# 258          15
# 259          16
# 260          15
#
# [261 rows x 1 columns]

# %% [markdown]
# ## Ordering column names sensibly

# %%
cars
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
ccategory=["mpg","weightlbs","year","brand"]
ccategory
# Out:
# ['mpg', 'weightlbs', 'year', 'brand']

# %%
cnum=["cylinders","cubicinches",'hp','time-to-60']
cnum
# Out:
# ['cylinders', 'cubicinches', 'hp', 'time-to-60']

# %%
c=ccategory+cnum
c
# Out:
# ['mpg',
#  'weightlbs',
#  'year',
#  'brand',
#  'cylinders',
#  'cubicinches',
#  'hp',
#  'time-to-60']

# %%
#Concatenate all the lists together to get the final column order
#Pass the list with the new column order to the indexing operator of the
    #DataFrame to reorder the columns:

cars2=cars[c]
cars2
# Out:
#       mpg weightlbs  year     brand  cylinders cubicinches   hp  time-to-60
# 0    14.0      4209  1972       US.          8         350  165          12
# 1    31.9      1925  1980   Europe.          4          89   71          14
# 2    17.0      3449  1971       US.          8         302  140          11
# 3    15.0      3761  1971       US.          8         400  150          10
# 4    30.5      2051  1978       US.          4          98   63          17
# ..    ...       ...   ...       ...        ...         ...  ...         ...
# 256  17.0      3840  1980       US.          8         305  130          15
# 257  36.1      1800  1979    Japan.          4          91   60          16
# 258  22.0      2835  1983       US.          6         232  112          15
# 259  18.0      3288  1972       US.          6         232  100          16
# 260  22.0      3353  1977       US.          6         250  105          15
#
# [261 rows x 8 columns]

# %% [markdown]
# ## Operating on the entire DataFrame

# %%
cars
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
cars.shape
# Out:
# (261, 8)

# %%
cars.size
# Out:
# 2088

# %%
cars.ndim
# Out:
# 2

# %%
cars.values
# Out:
# array([[14.0, 8, '350', ..., 12, 1972, ' US.'],
#        [31.9, 4, '89', ..., 14, 1980, ' Europe.'],
#        [17.0, 8, '302', ..., 11, 1971, ' US.'],
#        ...,
#        [22.0, 6, '232', ..., 15, 1983, ' US.'],
#        [18.0, 6, '232', ..., 16, 1972, ' US.'],
#        [22.0, 6, '250', ..., 15, 1977, ' US.']], dtype=object)

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=261, step=1)

# %%
cars.columns
# Out:
# Index(['mpg', 'cylinders', 'cubicinches', 'hp', 'weightlbs', 'time-to-60',
#        'year', 'brand'],
#       dtype='object')

# %%
cars.count()
# Out:
# mpg            261
# cylinders      261
# cubicinches    261
# hp             261
# weightlbs      261
# time-to-60     261
# year           261
# brand          261
# dtype: int64

# %%
cars.value_counts()
# Out:
# mpg   cylinders  cubicinches  hp   weightlbs  time-to-60  year  brand
# 10.0  8          360          215  4615       14          1971   US.        1
# 25.8  4          156          92   2620       14          1982   US.        1
# 26.0  4          156          92   2585       15          1983   US.        1
#                  79           67   1963       16          1975   Europe.    1
#                  91           70   1955       21          1972   US.        1
#                                                                            ..
# 18.1  8          302          139  3205       11          1979   US.        1
# 18.2  8          318          135  3830       15          1980   US.        1
# 18.5  6          250          98   3525       19          1978   US.        1
#                               110  3645       16          1977   US.        1
# 46.6  4          86           65   2110       18          1981   Japan.     1
# Length: 261, dtype: int64

# %%
len(cars)
# Out:
# 261

# %%
#The other methods that compute summary statistics such as min, max, mean,median, and std all return similar Series, with column names in the index and their computational result as the values:
cars.min()
# Out:
# mpg                10.0
# cylinders             3
# cubicinches
# hp                   46
# weightlbs
# time-to-60            8
# year               1971
# brand           Europe.
# dtype: object

# %%
cars.min(axis=1)
# Out:
# C:\Users\ss\AppData\Local\Temp\ipykernel_4564\1172095533.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cars.min(axis=1)
# 0      8.0
# 1      4.0
# 2      8.0
# 3      8.0
# 4      4.0
#       ...
# 256    8.0
# 257    4.0
# 258    6.0
# 259    6.0
# 260    6.0
# Length: 261, dtype: float64

# %%
cars.mpg.min()
# Out:
# 10.0

# %%
cars.mpg.max()
# Out:
# 46.6

# %%
cars.std()
# Out:
# C:\Users\ss\AppData\Local\Temp\ipykernel_4564\2703001680.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   cars.std()
# mpg            7.823570
# cylinders      1.733310
# hp            40.499959
# time-to-60     2.910625
# year           3.637696
# dtype: float64

# %%
cars.mpg.std()
# Out:
# 7.823570284044871

# %%
cars.corr()
# Out:
#                  mpg  cylinders        hp  time-to-60      year
# mpg         1.000000  -0.776710 -0.774905    0.509070  0.550441
# cylinders  -0.776710   1.000000  0.845155   -0.578161 -0.322239
# hp         -0.774905   0.845155  1.000000   -0.744873 -0.383869
# time-to-60  0.509070  -0.578161 -0.744873    1.000000  0.312311
# year        0.550441  -0.322239 -0.383869    0.312311  1.000000

# %%
cars.describe()
# Out:
#               mpg   cylinders          hp  time-to-60         year
# count  261.000000  261.000000  261.000000  261.000000   261.000000
# mean    23.144828    5.590038  106.360153   15.547893  1976.819923
# std      7.823570    1.733310   40.499959    2.910625     3.637696
# min     10.000000    3.000000   46.000000    8.000000  1971.000000
# 25%     16.900000    4.000000   75.000000   14.000000  1974.000000
# 50%     22.000000    6.000000   95.000000   16.000000  1977.000000
# 75%     28.800000    8.000000  138.000000   17.000000  1980.000000
# max     46.600000    8.000000  230.000000   25.000000  1983.000000

# %%
cars.describe(percentiles=[0.01,0.03,0.024,0.65,0.88])
# Out:
#               mpg   cylinders          hp  time-to-60         year
# count  261.000000  261.000000  261.000000  261.000000   261.000000
# mean    23.144828    5.590038  106.360153   15.547893  1976.819923
# std      7.823570    1.733310   40.499959    2.910625     3.637696
# min     10.000000    3.000000   46.000000    8.000000  1971.000000
# 1%      11.600000    4.000000   48.000000    9.000000  1971.000000
# 2.4%    12.240000    4.000000   52.000000   10.000000  1971.000000
# 3%      13.000000    4.000000   52.800000   10.000000  1971.000000
# 50%     22.000000    6.000000   95.000000   16.000000  1977.000000
# 65%     26.000000    6.000000  110.000000   16.000000  1979.000000
# 88%     32.980000    8.000000  151.600000   19.000000  1982.000000
# max     46.600000    8.000000  230.000000   25.000000  1983.000000

# %%
cars.quantile([0.01,0.03,0.024,0.65,0.88])
# Out:
#          mpg  cylinders     hp  time-to-60    year
# 0.010  11.60        4.0   48.0         9.0  1971.0
# 0.030  13.00        4.0   52.8        10.0  1971.0
# 0.024  12.24        4.0   52.0        10.0  1971.0
# 0.650  26.00        6.0  110.0        16.0  1979.0
# 0.880  32.98        8.0  151.6        19.0  1982.0

# %% [markdown]
# ## Chaining DataFrame methods together

# %%
employee=pd.read_csv("EMPLOYEES.csv")

# %%
employee
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# 0                      3             0     1                      0
# 1                      6             0     1                      0
# 2                      4             0     1                      0
# 3                      3             0     1                      0
# 4                      3             0     1                      0
# ...                  ...           ...   ...                    ...
# 14994                  4             0     1                      0
# 14995                  2             0     0                      0
# 14996                  4             0     0                      0
# 14997                  5             0     0                      0
# 14998                  3             0     0                      0
#
#             dept  salary
# 0          sales     low
# 1          sales  medium
# 2          sales  medium
# 3          sales     low
# 4          sales     low
# ...          ...     ...
# 14994    support  medium
# 14995      sales     low
# 14996  technical     low
# 14997      sales     low
# 14998    support     low
#
# [14999 rows x 10 columns]

# %%
#1. To get a count of the missing values, the isnull method must first be called to
#change each DataFrame value to a boolean. Let's call this method on the movie dataset:

employee.isnull().head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0              False           False             False            False
# 1              False           False             False            False
# 2              False           False             False            False
# 3              False           False             False            False
# 4              False           False             False            False
#
#    timeSpent.company  workAccident   left  promotionInLast5years   dept  \
# 0              False         False  False                  False  False
# 1              False         False  False                  False  False
# 2              False         False  False                  False  False
# 3              False         False  False                  False  False
# 4              False         False  False                  False  False
#
#    salary
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False

# %%
#2. We will chain the sum method that interprets True/False booleans as 1/0. Notice that a Series is returned:

employee.isnull().sum().head()         # resultant is series
# Out:
# satisfactoryLevel    0
# lastEvaluation       0
# numberOfProjects     0
# avgMonthlyHours      0
# timeSpent.company    0
# dtype: int64

# %%
#3. We can go one step further and take the sum of this Series and return the count of
#the total number of missing values in the entire DataFrame as a scalar value:

employee.isnull().sum().sum()
# Out:
# 0

# %%
dist=pd.read_csv("distillation-tower.csv")

# %%
dist
# Out:
#            Date     Temp1    FlowC1     Temp2    TempC1     Temp3    TempC2  \
# 0    2000-08-21  139.9857  432.0636  377.8119  100.2204  492.1353  490.1459
# 1    2000-08-23  131.0470  487.4029  371.3060  100.2297  482.2100  480.3128
# 2    2000-08-26  118.2666  437.3516  378.4483  100.3084  488.7266  487.0040
# 3    2000-08-29  118.1769  481.8314  378.0028   95.5766  493.1481  491.1137
# 4    2000-08-30  120.7891  412.6471  377.8871   92.9052  490.2486  488.6641
# ..          ...       ...       ...       ...       ...       ...       ...
# 248  2003-01-26  130.8138  212.6385  341.5964  121.4354  468.3401  467.0299
# 249  2003-01-28  128.9673  225.1412  349.8965  118.8604  479.7665  478.4652
# 250  2003-01-31  130.5328  223.5965  345.9366  120.4027  474.5378  473.1145
# 251  2003-02-03  128.5248  213.5613  343.4950  119.6989  469.3802  467.9954
# 252  2003-02-04  131.0491  217.4117  346.1960  119.0825  474.6599  473.0381
#
#        TempC3     Temp4  PressureC1  ...    Temp10  FlowC3   FlowC4   Temp11  \
# 0    180.5578  187.4331    215.0627  ...  513.9653  8.6279  10.5988  30.8983
# 1    172.6575  179.5089    205.0999  ...  504.5145  8.7662  10.7560  31.9099
# 2    165.9400  172.9262    205.0304  ...  508.9997  8.5319  10.5737  29.9165
# 3    167.2085  174.2338    205.2561  ...  514.1794  8.6260  10.6695  30.6229
# 4    167.0326  173.9681    205.0883  ...  511.0948  8.5939  10.4922  29.4977
# ..        ...       ...         ...  ...       ...     ...      ...      ...
# 248  174.7639  180.7649    229.7393  ...  479.0290  5.5590   6.4470  16.4131
# 249  176.2176  182.3646    230.5049  ...  491.2362  5.6342   6.4360  17.2385
# 250  176.3310  182.2578    230.6638  ...  485.8786  5.4810   6.3575  16.9866
# 251  174.6435  180.5093    230.5226  ...  480.2879  5.4727   6.4175  16.6778
# 252  177.1088  183.1810    225.6420  ...  486.0253  5.4597   6.3291  16.8766
#
#        Temp12  InvTemp1  InvTemp2  InvTemp3  InvPressure1  VapourPressure
# 0    489.9900    2.0409    2.6468    2.1681        4.3524         32.5026
# 1    480.2888    2.0821    2.6932    2.2207        4.5497         34.8598
# 2    486.6190    2.0550    2.6424    2.1796        4.5511         32.1666
# 3    491.1304    2.0361    2.6455    2.1620        4.5464         30.4064
# 4    487.6475    2.0507    2.6463    2.1704        4.5499         30.9238
# ..        ...       ...       ...       ...           ...             ...
# 248  466.3347    2.1444    2.9274    2.2127        4.0911         38.8507
# 249  477.8816    2.0926    2.8580    2.1620        4.0783         34.2653
# 250  472.3176    2.1172    2.8907    2.1855        4.0756         36.5717
# 251  467.0001    2.1413    2.9113    2.2090        4.0780         38.1054
# 252  472.2701    2.1174    2.8885    2.1844        4.1608         35.6298
#
# [253 rows x 28 columns]

# %%
dist.isnull().sum().sum()
# Out:
# 0

# %%
data=pd.read_csv("D:/DOWNLOAD/data.csv")

# %%
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 5

# %%
#4. A slight deviation is to determine whether there are any missing values in the
#DataFrame. We use the any method here twice in succession to do this:

data.isnull().any().any()
# Out:
# True

# %%
#To force pandas to return something for each column, we must fill in the missing values.
#Here, we choose an empty column:
#>>> movie.select_dtypes(['object']).fillna('').min()       # for object columns 
data.select_dtypes(['int']).fillna(0).min()
# Out:
# Duration     15
# Pulse        80
# Maxpulse    100
# dtype: int64

# %%
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data.isnull().sum().sum()
# Out:
# 5

# %% [markdown]
# ## Working with operators on a DataFrame

# %%
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
data+0.05
# Out:
#      Duration   Pulse  Maxpulse  Calories
# 0       60.05  110.05    130.05    409.15
# 1       60.05  117.05    145.05    479.05
# 2       60.05  103.05    135.05    340.05
# 3       45.05  109.05    175.05    282.45
# 4       45.05  117.05    148.05    406.05
# ..        ...     ...       ...       ...
# 164     60.05  105.05    140.05    290.85
# 165     60.05  110.05    145.05    300.05
# 166     60.05  115.05    145.05    310.25
# 167     75.05  120.05    150.05    320.45
# 168     75.05  125.05    150.05    330.45
#
# [169 rows x 4 columns]

# %%
data.Pulse+0.25
# Out:
# 0      110.25
# 1      117.25
# 2      103.25
# 3      109.25
# 4      117.25
#         ...
# 164    105.25
# 165    110.25
# 166    115.25
# 167    120.25
# 168    125.25
# Name: Pulse, Length: 169, dtype: float64

# %%
data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
#1 Use the floor division operator, //, to round to the nearest whole numberpercentage:
 
data//4
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          15     27        32     102.0
# 1          15     29        36     119.0
# 2          15     25        33      85.0
# 3          11     27        43      70.0
# 4          11     29        37     101.0
# ..        ...    ...       ...       ...
# 164        15     26        35      72.0
# 165        15     27        36      75.0
# 166        15     28        36      77.0
# 167        18     30        37      80.0
# 168        18     31        37      82.0
#
# [169 rows x 4 columns]

# %%
#2. To complete the rounding exercise, divide by 100
data/100
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        0.60   1.10      1.30     4.091
# 1        0.60   1.17      1.45     4.790
# 2        0.60   1.03      1.35     3.400
# 3        0.45   1.09      1.75     2.824
# 4        0.45   1.17      1.48     4.060
# ..        ...    ...       ...       ...
# 164      0.60   1.05      1.40     2.908
# 165      0.60   1.10      1.45     3.000
# 166      0.60   1.15      1.45     3.102
# 167      0.75   1.20      1.50     3.204
# 168      0.75   1.25      1.50     3.304
#
# [169 rows x 4 columns]

# %%
(data+0.05)//0.1/100
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0         6.0   11.0      13.0     40.91
# 1         6.0   11.7      14.5     47.90
# 2         6.0   10.3      13.5     34.00
# 3         4.5   10.9      17.5     28.24
# 4         4.5   11.7      14.8     40.60
# ..        ...    ...       ...       ...
# 164       6.0   10.5      14.0     29.08
# 165       6.0   11.0      14.5     30.00
# 166       6.0   11.5      14.5     31.02
# 167       7.5   12.0      15.0     32.04
# 168       7.5   12.5      15.0     33.04
#
# [169 rows x 4 columns]

# %%
#Now use the round DataFrame method to do the rounding automatically for us.

data.Calories.round(1)
# Out:
# 0      409.1
# 1      479.0
# 2      340.0
# 3      282.4
# 4      406.0
#        ...
# 164    290.8
# 165    300.0
# 166    310.2
# 167    320.4
# 168    330.4
# Name: Calories, Length: 169, dtype: float64

# %%
#Just as with Series, DataFrames have method equivalents of the operators.replace the operators with their method equivalents:

data.add(.00501) \
 .floordiv(.01) \
 .div(100)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0        60.0  110.0     130.0     409.1
# 1        60.0  117.0     145.0     479.0
# 2        60.0  103.0     135.0     340.0
# 3        45.0  109.0     175.0     282.4
# 4        45.0  117.0     148.0     406.0
# ..        ...    ...       ...       ...
# 164      60.0  105.0     140.0     290.8
# 165      60.0  110.0     145.0     300.0
# 166      60.0  115.0     145.0     310.2
# 167      75.0  120.0     150.0     320.4
# 168      75.0  125.0     150.0     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# ## Comparing missing values

# %% [raw]
# Pandas uses the NumPy NaN (np.nan) object to represent a missing value. This is an
# unusual object, as it is not equal to itself. Even Python's None object evaluates as True when
# compared to itself:

# %%
np.nan == np.nan
# Out:
# False

# %%
None == None
# Out:
# True

# %%
#All other comparisons against np.nan also return False, except not equal to:
np.nan > 5
# Out:
# False

# %%
np.nan != 5
# Out:
# True

# %%
#1. To get an idea of how the equals operator works, let's compare each element to a scalar value:

data==0.009
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
a=data==0.09
a
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
a.any()
# Out:
# Duration    False
# Pulse       False
# Maxpulse    False
# Calories    False
# dtype: bool

# %%
#4. This happens because missing values do not compare equally with one another. If
#you tried to count missing values using the equal operator and summing up the
#boolean columns, you would get zero for each one:
(data== np.nan).sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
#5. The primary way to count missing values uses the isnull method:
data.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
#6. The correct way to compare two entire DataFrames with one another is not with the equals operator but with the equals method:

data.equals(a)
# Out:
# False

# %%
a.equals(data)
# Out:
# False
