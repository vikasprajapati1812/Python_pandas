# %% [markdown]
# # Chapter 6  Index Alignment

# %% [raw]
# #In this chapter, we will cover the following topics:
# 1.Examining the Index object
# 2.Producing Cartesian products
# 3.Exploding indexes
# 4.Filling values with unequal indexes
# 5.Appending columns from different DataFrames
# 6.Highlighting the maximum value from each column
# 7.Replicating idxmax with method chaining
# 8.Finding the most common maximum

# %% [markdown]
# # 1.Examining the Index object

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#1. Read in the college dataset, assign for the column index to a variable, and output it:
college = pd.read_csv('college.csv')
columns = college.columns
columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
#2. Use the values attribute to access the underlying NumPy array:
columns.values
# Out:
# array(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY',
#        'RELAFFIL', 'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS',
#        'UGDS_WHITE', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN',
#        'UGDS_NHPI', 'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF',
#        'CURROPER', 'PCTPELL', 'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10',
#        'GRAD_DEBT_MDN_SUPP'], dtype=object)

# %%
#3. Select items from the index by integer location with scalars, lists, or slices:
columns[5]
# Out:
# 'WOMENONLY'

# %%
columns[[1,8,10]]
# Out:
# Index(['CITY', 'SATMTMID', 'UGDS'], dtype='object')

# %%
columns[-7:-4]
# Out:
# Index(['PPTUG_EF', 'CURROPER', 'PCTPELL'], dtype='object')

# %%
#4. Indexes share many of the same methods as Series and DataFrames:
columns.min(), columns.max(), columns.isnull().sum()
# Out:
# ('CITY', 'WOMENONLY', 0)

# %%
columns.isnull().sum() # counts no. of the null values in the columns
# Out:
# 0

# %%
#5. Use basic arithmetic and comparison operators directly on Index objects:
columns + '_A'
# Out:
# Index(['INSTNM_A', 'CITY_A', 'STABBR_A', 'HBCU_A', 'MENONLY_A', 'WOMENONLY_A',
#        'RELAFFIL_A', 'SATVRMID_A', 'SATMTMID_A', 'DISTANCEONLY_A', 'UGDS_A',
#        'UGDS_WHITE_A', 'UGDS_BLACK_A', 'UGDS_HISP_A', 'UGDS_ASIAN_A',
#        'UGDS_AIAN_A', 'UGDS_NHPI_A', 'UGDS_2MOR_A', 'UGDS_NRA_A',
#        'UGDS_UNKN_A', 'PPTUG_EF_A', 'CURROPER_A', 'PCTPELL_A', 'PCTFLOAN_A',
#        'UG25ABV_A', 'MD_EARN_WNE_P10_A', 'GRAD_DEBT_MDN_SUPP_A'],
#       dtype='object')

# %%
columns > 'G'
# Out:
# array([ True, False,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True])

# %%
#6. Trying to change an Index value directly after its creation fails. Indexes are immutable objects:
columns[1] = 'city'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 #6. Trying to change an Index value directly after its creation fails. Indexes are immutable objects:
# ----> 2 columns[1] = 'city'
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:5021, in Index.__setitem__(self, key, value)
#    5019 @final
#    5020 def __setitem__(self, key, value):
# -> 5021     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
#Indexes support the set operations, union, intersection, difference, and symmetric difference:
c1 = columns[:4]
c1
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU'], dtype='object')

# %%
c2 = columns[2:6]
c2
# Out:
# Index(['STABBR', 'HBCU', 'MENONLY', 'WOMENONLY'], dtype='object')

# %%
c1.union(c2) # or `c1 | c2`
# Out:
# Index(['CITY', 'HBCU', 'INSTNM', 'MENONLY', 'STABBR', 'WOMENONLY'], dtype='object')

# %%
c1.symmetric_difference(c2) # or `c1 ^ c2`
# Out:
# Index(['CITY', 'INSTNM', 'MENONLY', 'WOMENONLY'], dtype='object')

# %%
c1
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU'], dtype='object')

# %%
c2
# Out:
# Index(['STABBR', 'HBCU', 'MENONLY', 'WOMENONLY'], dtype='object')

# %% [markdown]
# # 2.Producing Cartesian products

# %%
#1. Construct two Series that have indexes that are different but contain some of the same values:
s1 = pd.Series(index=list('aaab'), data=np.arange(4))
s1
# Out:
# a    0
# a    1
# a    2
# b    3
# dtype: int32

# %%
s2 = pd.Series(index=list('cababb'), data=np.arange(6))
s2
# Out:
# c    0
# a    1
# b    2
# a    3
# b    4
# b    5
# dtype: int32

# %%
#2. Add the two Series together to produce a Cartesian product:
s1 + s2
# Out:
# a    1.0
# a    3.0
# a    2.0
# a    4.0
# a    3.0
# a    5.0
# b    5.0
# b    7.0
# b    8.0
# c    NaN
# dtype: float64

# %%
s1 = pd.Series(index=list('aaabb'), data=np.arange(5))
s2 = pd.Series(index=list('aaabb'), data=np.arange(5))
s1 + s2
# Out:
# a    0
# a    2
# a    4
# b    6
# b    8
# dtype: int32

# %%
"""If the elements of the index are identical, but the order is different between the Series, a
Cartesian product occurs. Let's change the order of the index in s2 and rerun the same
operation:
"""    
s1 = pd.Series(index=list('aaabb'), data=np.arange(5))
s2 = pd.Series(index=list('bbaaa'), data=np.arange(5))
s1 + s2
# Out:
# a    2
# a    3
# a    4
# a    3
# a    4
# a    5
# a    4
# a    5
# a    6
# b    3
# b    4
# b    4
# b    5
# dtype: int32

# %% [markdown]
# # 3.Exploding indexes
# The previous recipe walked through a trivial example of two small Series being added
# together with unequal indexes. This problem can produce comically incorrect results when
# dealing with larger data.

# %%
#1.1. Read in the employee data and set the index equal to the race column:
movie= pd.read_csv('movie.csv')
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
# 3                 27000.0  448130642.0                  Action|Thriller  ...
# 4                   131.0          NaN                      Documentary  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# 0               3054.0  English      USA           PG-13  237000000.0
# 1               1238.0  English      USA           PG-13  300000000.0
# 2                994.0  English       UK           PG-13  245000000.0
# 3               2701.0  English      USA           PG-13  250000000.0
# 4                  NaN      NaN      NaN             NaN          NaN
#
#    title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0      2009.0                  936.0        7.9          1.78
# 1      2007.0                 5000.0        7.1          2.35
# 2      2015.0                  393.0        6.8          2.35
# 3      2012.0                23000.0        8.5          2.35
# 4         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
review1=movie["num_critic_for_reviews"]
review2=movie["num_critic_for_reviews"]
review1 is review2      #The salary1 and salary2 variables are actually referring to the same object.
                        #This means that any change to one will change the other. To ensure that you
                        #receive a brand new copy of the data, use the copy method:
# Out:
# True

# %%
review1=movie["num_critic_for_reviews"].copy()
review2=movie["num_critic_for_reviews"].copy()
review1 is review2
# Out:
# False

# %%
#4. Let's change the order of the index for one of the Series by sorting it:
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 4911                   637.0          NaN                     Comedy|Drama
# 4912                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 4913                     0.0          NaN            Drama|Horror|Thriller
# 4914                   946.0      10443.0             Comedy|Drama|Romance
# 4915                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 4911  ...                  6.0  English   Canada             NaN          NaN
# 4912  ...                359.0  English      USA           TV-14          NaN
# 4913  ...                  3.0  English      USA             NaN       1400.0
# 4914  ...                  9.0  English      USA           PG-13          NaN
# 4915  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 4911      2013.0                  470.0        7.7           NaN
# 4912         NaN                  593.0        7.5         16.00
# 4913      2013.0                    0.0        6.3           NaN
# 4914      2012.0                  719.0        6.3          2.35
# 4915      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 4911                   84
# 4912                32000
# 4913                   16
# 4914                  660
# 4915                  456
#
# [4916 rows x 28 columns]

# %%
movies=pd.read_csv("movie.csv",index_col="genres")

# %%
movies
# Out:
#                                  color      director_name  \
# genres
# Action|Adventure|Fantasy|Sci-Fi  Color      James Cameron
# Action|Adventure|Fantasy         Color     Gore Verbinski
# Action|Adventure|Thriller        Color         Sam Mendes
# Action|Thriller                  Color  Christopher Nolan
# Documentary                        NaN        Doug Walker
# ...                                ...                ...
# Comedy|Drama                     Color        Scott Smith
# Crime|Drama|Mystery|Thriller     Color                NaN
# Drama|Horror|Thriller            Color   Benjamin Roberds
# Comedy|Drama|Romance             Color        Daniel Hsia
# Documentary                      Color           Jon Gunn
#
#                                  num_critic_for_reviews  duration  \
# genres
# Action|Adventure|Fantasy|Sci-Fi                   723.0     178.0
# Action|Adventure|Fantasy                          302.0     169.0
# Action|Adventure|Thriller                         602.0     148.0
# Action|Thriller                                   813.0     164.0
# Documentary                                         NaN       NaN
# ...                                                 ...       ...
# Comedy|Drama                                        1.0      87.0
# Crime|Drama|Mystery|Thriller                       43.0      43.0
# Drama|Horror|Thriller                              13.0      76.0
# Comedy|Drama|Romance                               14.0     100.0
# Documentary                                        43.0      90.0
#
#                                  director_facebook_likes  \
# genres
# Action|Adventure|Fantasy|Sci-Fi                      0.0
# Action|Adventure|Fantasy                           563.0
# Action|Adventure|Thriller                            0.0
# Action|Thriller                                  22000.0
# Documentary                                        131.0
# ...                                                  ...
# Comedy|Drama                                         2.0
# Crime|Drama|Mystery|Thriller                         NaN
# Drama|Horror|Thriller                                0.0
# Comedy|Drama|Romance                                 0.0
# Documentary                                         16.0
#
#                                  actor_3_facebook_likes      actor_2_name  \
# genres
# Action|Adventure|Fantasy|Sci-Fi                   855.0  Joel David Moore
# Action|Adventure|Fantasy                         1000.0     Orlando Bloom
# Action|Adventure|Thriller                         161.0      Rory Kinnear
# Action|Thriller                                 23000.0    Christian Bale
# Documentary                                         NaN        Rob Walker
# ...                                                 ...               ...
# Comedy|Drama                                      318.0     Daphne Zuniga
# Crime|Drama|Mystery|Thriller                      319.0     Valorie Curry
# Drama|Horror|Thriller                               0.0     Maxwell Moody
# Comedy|Drama|Romance                              489.0     Daniel Henney
# Documentary                                        16.0  Brian Herzlinger
#
#                                  actor_1_facebook_likes        gross  \
# genres
# Action|Adventure|Fantasy|Sci-Fi                  1000.0  760505847.0
# Action|Adventure|Fantasy                        40000.0  309404152.0
# Action|Adventure|Thriller                       11000.0  200074175.0
# Action|Thriller                                 27000.0  448130642.0
# Documentary                                       131.0          NaN
# ...                                                 ...          ...
# Comedy|Drama                                      637.0          NaN
# Crime|Drama|Mystery|Thriller                      841.0          NaN
# Drama|Horror|Thriller                               0.0          NaN
# Comedy|Drama|Romance                              946.0      10443.0
# Documentary                                        86.0      85222.0
#
#                                     actor_1_name  ... num_user_for_reviews  \
# genres                                            ...
# Action|Adventure|Fantasy|Sci-Fi      CCH Pounder  ...               3054.0
# Action|Adventure|Fantasy             Johnny Depp  ...               1238.0
# Action|Adventure|Thriller        Christoph Waltz  ...                994.0
# Action|Thriller                        Tom Hardy  ...               2701.0
# Documentary                          Doug Walker  ...                  NaN
# ...                                          ...  ...                  ...
# Comedy|Drama                         Eric Mabius  ...                  6.0
# Crime|Drama|Mystery|Thriller         Natalie Zea  ...                359.0
# Drama|Horror|Thriller                Eva Boehnke  ...                  3.0
# Comedy|Drama|Romance                   Alan Ruck  ...                  9.0
# Documentary                          John August  ...                 84.0
#
#                                  language  country content_rating  \
# genres
# Action|Adventure|Fantasy|Sci-Fi   English      USA          PG-13
# Action|Adventure|Fantasy          English      USA          PG-13
# Action|Adventure|Thriller         English       UK          PG-13
# Action|Thriller                   English      USA          PG-13
# Documentary                           NaN      NaN            NaN
# ...                                   ...      ...            ...
# Comedy|Drama                      English   Canada            NaN
# Crime|Drama|Mystery|Thriller      English      USA          TV-14
# Drama|Horror|Thriller             English      USA            NaN
# Comedy|Drama|Romance              English      USA          PG-13
# Documentary                       English      USA             PG
#
#                                       budget title_year  \
# genres
# Action|Adventure|Fantasy|Sci-Fi  237000000.0     2009.0
# Action|Adventure|Fantasy         300000000.0     2007.0
# Action|Adventure|Thriller        245000000.0     2015.0
# Action|Thriller                  250000000.0     2012.0
# Documentary                              NaN        NaN
# ...                                      ...        ...
# Comedy|Drama                             NaN     2013.0
# Crime|Drama|Mystery|Thriller             NaN        NaN
# Drama|Horror|Thriller                 1400.0     2013.0
# Comedy|Drama|Romance                     NaN     2012.0
# Documentary                           1100.0     2004.0
#
#                                 actor_2_facebook_likes  imdb_score  \
# genres
# Action|Adventure|Fantasy|Sci-Fi                  936.0         7.9
# Action|Adventure|Fantasy                        5000.0         7.1
# Action|Adventure|Thriller                        393.0         6.8
# Action|Thriller                                23000.0         8.5
# Documentary                                       12.0         7.1
# ...                                                ...         ...
# Comedy|Drama                                     470.0         7.7
# Crime|Drama|Mystery|Thriller                     593.0         7.5
# Drama|Horror|Thriller                              0.0         6.3
# Comedy|Drama|Romance                             719.0         6.3
# Documentary                                       23.0         6.6
#
#                                 aspect_ratio movie_facebook_likes
# genres
# Action|Adventure|Fantasy|Sci-Fi         1.78                33000
# Action|Adventure|Fantasy                2.35                    0
# Action|Adventure|Thriller               2.35                85000
# Action|Thriller                         2.35               164000
# Documentary                              NaN                    0
# ...                                      ...                  ...
# Comedy|Drama                             NaN                   84
# Crime|Drama|Mystery|Thriller           16.00                32000
# Drama|Horror|Thriller                    NaN                   16
# Comedy|Drama|Romance                    2.35                  660
# Documentary                             1.85                  456
#
# [4916 rows x 27 columns]

# %%
movies.sort_index()
# Out:
#          color      director_name  num_critic_for_reviews  duration  \
# genres
# Action   Color         Alec Asten                     1.0      82.0
# Action     NaN     John Stockwell                     2.0      90.0
# Action   Color                RZA                   208.0     107.0
# Action   Color         Tim Burton                   153.0     126.0
# Action   Color        Chao-Bin Su                    50.0     117.0
# ...        ...                ...                     ...       ...
# Western  Color    Robert M. Young                     NaN     105.0
# Western  Color     Clint Eastwood                    38.0     115.0
# Western  Color  Leonard Farlinger                     8.0      89.0
# Western  Color          John Ford                    55.0     103.0
# Western  Color       Sergio Leone                   181.0     142.0
#
#          director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# genres
# Action                       5.0                   237.0   Dennis L.A. White
# Action                     134.0                   354.0          T.J. Storm
# Action                     561.0                   353.0                 RZA
# Action                   13000.0                   390.0  Vincent Schiavelli
# Action                       2.0                    21.0           Shawn Yue
# ...                          ...                     ...                 ...
# Western                      0.0                   467.0        Bruce McGill
# Western                  16000.0                   240.0          Chris Penn
# Western                      0.0                   413.0         Gary Farmer
# Western                    673.0                    89.0         Ben Johnson
# Western                      0.0                    24.0      Luigi Pistilli
#
#          actor_1_facebook_likes        gross     actor_1_name  ...  \
# genres                                                         ...
# Action                    472.0          NaN     Luis Sanchez  ...
# Action                 260000.0          NaN     Matthew Ziff  ...
# Action                    746.0   15608545.0        Rick Yune  ...
# Action                    920.0  162831698.0    Michael Gough  ...
# Action                    149.0          NaN    Woo-sung Jung  ...
# ...                         ...          ...              ...  ...
# Western                   883.0          NaN     Barry Corbin  ...
# Western                 16000.0   41400000.0   Clint Eastwood  ...
# Western                   584.0          NaN  Keith Carradine  ...
# Western                   281.0          NaN  Harry Carey Jr.  ...
# Western                 16000.0    6100000.0   Clint Eastwood  ...
#
#         num_user_for_reviews  language  country content_rating      budget  \
# genres
# Action                   5.0   English      USA              R    500000.0
# Action                   1.0       NaN      USA            NaN  17000000.0
# Action                 224.0   English      USA              R  15000000.0
# Action                 610.0   English      USA          PG-13  80000000.0
# Action                  34.0  Mandarin    China              R  12000000.0
# ...                      ...       ...      ...            ...         ...
# Western                  2.0   English      USA            NaN   1250000.0
# Western                138.0   English      USA              R   6900000.0
# Western                  8.0   English   Canada              R   5000000.0
# Western                 90.0   English      USA        Unrated   1600000.0
# Western                780.0   Italian    Italy       Approved   1200000.0
#
#         title_year actor_2_facebook_likes  imdb_score aspect_ratio  \
# genres
# Action      2015.0                  251.0         4.3          NaN
# Action      2016.0                  454.0         9.1          NaN
# Action      2012.0                  561.0         5.4         2.35
# Action      1992.0                  811.0         7.0         1.85
# Action      2010.0                   32.0         6.9         2.35
# ...            ...                    ...         ...          ...
# Western     1982.0                  655.0         7.1          NaN
# Western     1985.0                  455.0         7.3         2.35
# Western     2007.0                  580.0         5.3         2.35
# Western     1949.0                  230.0         7.4         1.37
# Western     1966.0                   34.0         8.9         2.35
#
#         movie_facebook_likes
# genres
# Action                    62
# Action                     0
# Action                 29000
# Action                     0
# Action                  1000
# ...                      ...
# Western                   32
# Western                    0
# Western                   31
# Western                  721
# Western                20000
#
# [4916 rows x 27 columns]

# %%
movies=movies.sort_index()

# %%
movies
# Out:
#          color      director_name  num_critic_for_reviews  duration  \
# genres
# Action   Color         Alec Asten                     1.0      82.0
# Action     NaN     John Stockwell                     2.0      90.0
# Action   Color                RZA                   208.0     107.0
# Action   Color         Tim Burton                   153.0     126.0
# Action   Color        Chao-Bin Su                    50.0     117.0
# ...        ...                ...                     ...       ...
# Western  Color    Robert M. Young                     NaN     105.0
# Western  Color     Clint Eastwood                    38.0     115.0
# Western  Color  Leonard Farlinger                     8.0      89.0
# Western  Color          John Ford                    55.0     103.0
# Western  Color       Sergio Leone                   181.0     142.0
#
#          director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# genres
# Action                       5.0                   237.0   Dennis L.A. White
# Action                     134.0                   354.0          T.J. Storm
# Action                     561.0                   353.0                 RZA
# Action                   13000.0                   390.0  Vincent Schiavelli
# Action                       2.0                    21.0           Shawn Yue
# ...                          ...                     ...                 ...
# Western                      0.0                   467.0        Bruce McGill
# Western                  16000.0                   240.0          Chris Penn
# Western                      0.0                   413.0         Gary Farmer
# Western                    673.0                    89.0         Ben Johnson
# Western                      0.0                    24.0      Luigi Pistilli
#
#          actor_1_facebook_likes        gross     actor_1_name  ...  \
# genres                                                         ...
# Action                    472.0          NaN     Luis Sanchez  ...
# Action                 260000.0          NaN     Matthew Ziff  ...
# Action                    746.0   15608545.0        Rick Yune  ...
# Action                    920.0  162831698.0    Michael Gough  ...
# Action                    149.0          NaN    Woo-sung Jung  ...
# ...                         ...          ...              ...  ...
# Western                   883.0          NaN     Barry Corbin  ...
# Western                 16000.0   41400000.0   Clint Eastwood  ...
# Western                   584.0          NaN  Keith Carradine  ...
# Western                   281.0          NaN  Harry Carey Jr.  ...
# Western                 16000.0    6100000.0   Clint Eastwood  ...
#
#         num_user_for_reviews  language  country content_rating      budget  \
# genres
# Action                   5.0   English      USA              R    500000.0
# Action                   1.0       NaN      USA            NaN  17000000.0
# Action                 224.0   English      USA              R  15000000.0
# Action                 610.0   English      USA          PG-13  80000000.0
# Action                  34.0  Mandarin    China              R  12000000.0
# ...                      ...       ...      ...            ...         ...
# Western                  2.0   English      USA            NaN   1250000.0
# Western                138.0   English      USA              R   6900000.0
# Western                  8.0   English   Canada              R   5000000.0
# Western                 90.0   English      USA        Unrated   1600000.0
# Western                780.0   Italian    Italy       Approved   1200000.0
#
#         title_year actor_2_facebook_likes  imdb_score aspect_ratio  \
# genres
# Action      2015.0                  251.0         4.3          NaN
# Action      2016.0                  454.0         9.1          NaN
# Action      2012.0                  561.0         5.4         2.35
# Action      1992.0                  811.0         7.0         1.85
# Action      2010.0                   32.0         6.9         2.35
# ...            ...                    ...         ...          ...
# Western     1982.0                  655.0         7.1          NaN
# Western     1985.0                  455.0         7.3         2.35
# Western     2007.0                  580.0         5.3         2.35
# Western     1949.0                  230.0         7.4         1.37
# Western     1966.0                   34.0         8.9         2.35
#
#         movie_facebook_likes
# genres
# Action                    62
# Action                     0
# Action                 29000
# Action                     0
# Action                  1000
# ...                      ...
# Western                   32
# Western                    0
# Western                   31
# Western                  721
# Western                20000
#
# [4916 rows x 27 columns]

# %%
#5. Let's add these imdb_score Series together:
moviesadd=movies["imdb_score"]+movies["imdb_score"]
moviesadd.head
# Out:
# <bound method NDFrame.head of genres
# Action      8.6
# Action     18.2
# Action     10.8
# Action     14.0
# Action     13.8
#            ...
# Western    14.2
# Western    14.6
# Western    10.6
# Western    14.8
# Western    17.8
# Name: imdb_score, Length: 4916, dtype: float64>

# %% [markdown]
# #  4. Filling values with unequal indexes

# %% [raw]
# When two Series are added together using the plus operator and one of the index labels
# does not appear in the other, the resulting value is always missing. Pandas offers the add
# method, which provides an option to fill the missing value.
# Getting ready
# In this recipe, we add together multiple Series from the baseball dataset with unequal
# indexes using the fill_value parameter of the add method to ensure that there are no
# missing values in the result.
# Index Alignment
#
#
#
#
# How to do it...
# 1. Read in the three baseball datasets and set the index as playerID:
# >>> baseball_14 = pd.read_csv('data/baseball14.csv',
#  index_col='playerID')
# >>> baseball_15 = pd.read_csv('data/baseball15.csv',
#  index_col='playerID')
# >>> baseball_16 = pd.read_csv('data/baseball16.csv',
#  index_col='playerID')
# >>> baseball_14.head()
# 2. Use the index method difference to discover which index labels are in
# baseball_14 and not in baseball_15, and vice versa:
# >>> baseball_14.index.difference(baseball_15.index)
# Index(['corpoca01', 'dominma01', 'fowlede01', 'grossro01',
#  'guzmaje01', 'hoeslj01', 'krausma01', 'preslal01',
#  'singljo02'], dtype='object', name='playerID')
# >>> baseball_14.index.difference(baseball_16.index)
# Index(['congeha01', 'correca01', 'gattiev01', 'gomezca01',
#  'lowrije01', 'rasmuco01', 'tuckepr01', 'valbulu01'],
#  dtype='object', name='playerID')
# 3. There are quite a few players unique to each index. Let's find out how many hits
# each player has in total over the three-year period. The H column contains the
# number of hits:
# >>> hits_14 = baseball_14['H']
# >>> hits_15 = baseball_15['H']
# >>> hits_16 = baseball_16['H']
# >>> hits_14.head()
# playerID
# altuvjo01 225
# Index Alignment
#
#
#
# cartech02 115
# castrja01 103
# corpoca01 40
# dominma01 121
# Name: H, dtype: int64
# 4. Let's first add together two Series using the plus operator:
# >>> (hits_14 + hits_15).head()
# playerID
# altuvjo01 425.0
# cartech02 193.0
# castrja01 174.0
# congeha01 NaN
# corpoca01 NaN
# Name: H, dtype: float64
# 5. Even though players congeha01 and corpoca01 have recorded hits for 2015,
# their result is missing. Let's use the add method and its parameter, fill_value,
# to avoid missing values:
# >>> hits_14.add(hits_15, fill_value=0).head()
# playerID
# altuvjo01 425.0
# cartech02 193.0
# castrja01 174.0
# congeha01 46.0
# corpoca01 40.0
# Name: H, dtype: float64
# Index Alignment
#
#
#
#
# 6. We add hits from 2016 by chaining the add method once more:
# >>> hits_total = hits_14.add(hits_15, fill_value=0) \
#  .add(hits_16, fill_value=0)
# >>> hits_total.head()
# playerID
# altuvjo01 641.0
# bregmal01 53.0
# cartech02 193.0
# castrja01 243.0
# congeha01 46.0
# Name: H, dtype: float64
# 7. Check for missing values in the result:
# >>> hits_total.hasnans
# False
# How it works...
# The add method works similarly to the plus operator but allows for more flexibility by
# providing the fill_value parameter to take the place of a non-matching index. In this
# problem, it makes sense to default the non-matching index value to 0, but you could have
# used any other number.
# There will be occasions when each Series contains index labels that correspond to missing
# values. In this specific instance, when the two Series are added, the index label will still
# correspond to a missing value regardless if the fill_value parameter is used. To clarify
# this, take a look at the following example where the index label a corresponds to a missing
# value in each Series:
# >>> s = pd.Series(index=['a', 'b', 'c', 'd'],
#  data=[np.nan, 3, np.nan, 1])
# >>> s
# a NaN
# b 3.0
# c NaN
# d 1.0
# dtype: float64
# >>> s1 = pd.Series(index=['a', 'b', 'c'], data=[np.nan, 6, 10])
# >>> s1
# a NaN
# b 6.0
# c 10.0
# Index Alignment
#
#
#
# dtype: float64
# >>> s.add(s1, fill_value=5)
# a NaN
# b 9.0
# c 15.0
# d 6.0
# dtype: float64
# There's more...
# This recipe shows how to add Series with only a single index together. It is also entirely
# possible to add DataFrames together. Adding DataFrames together will align both the index
# and columns before computation and yield missing values for non-matching indexes. Let's
# start by selecting a few of the columns from the 2014 baseball dataset.
# >>> df_14 = baseball_14[['G','AB', 'R', 'H']]
# >>> df_14.head()
# Let's also select a few of the same and a few different columns from the 2015 baseball dataset:
# >>> df_15 = baseball_15[['AB', 'R', 'H', 'HR']]
# >>> df_15.head()
# Index Alignment
#
#
#
#
# Adding the two DataFrames together create missing values wherever rows or column labels
# cannot align. Use the style attribute to access the highlight_null method to easily see
# where the missing values are:
# >>> (df_14 + df_15).head(10).style.highlight_null('yellow')
# Only the rows with playerID appearing in both DataFrames will be non-missing.
# Similarly, the columns AB, H, and R are the only ones that appear in both DataFrames. Even
# if we use the add method with the fill_value parameter specified, we still have missing
# values. This is because some combinations of rows and columns never existed in our input
# data. For example, the intersection of playerID congeha01 and column G. He only appeared
# in the 2015 dataset that did not have the G column. Therefore, no value was filled with it:
# >>> df_14.add(df_15, fill_value=0).head(10) \
#  .style.highlight_null('yellow')
# Index Alignment

# %% [markdown]
# # 5.Appending columns from different DataFrames

# %%
# 1. Import the employee data and select the DEPARTMENT and BASE_SALARY
#columns in a new DataFrame:
employee = pd.read_csv('employee.csv')
dept_sal = employee[['DEPARTMENT', 'BASE_SALARY']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [40], in <cell line: 3>()
#       1 # 1. Import the employee data and select the DEPARTMENT and BASE_SALARY
#       2 #columns in a new DataFrame:
# ----> 3 employee = pd.read_csv('employee.csv')
#       4 dept_sal = employee[['DEPARTMENT', 'BASE_SALARY']]
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'employee.csv'

# %% [markdown]
# # Highlighting the maximum value from each column

# %% [markdown]
# # Replicating idxmax with method chaining

# %% [markdown]
# # Finding the most common maximum
